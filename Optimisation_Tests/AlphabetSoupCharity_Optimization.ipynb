# %% [markdown]
# ## Preprocessing

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf

#  Import and read the charity_data.csv.
import pandas as pd 
application_df = pd.read_csv("https://static.bc-edx.com/data/dl-1-2/m21/lms/starter/charity_data.csv")
application_df.head()
# Out:
#         EIN                                      NAME APPLICATION_TYPE  \
# 0  10520599              BLUE KNIGHTS MOTORCYCLE CLUB              T10
# 1  10531628    AMERICAN CHESAPEAKE CLUB CHARITABLE TR               T3
# 2  10547893        ST CLOUD PROFESSIONAL FIREFIGHTERS               T5
# 3  10553066            SOUTHSIDE ATHLETIC ASSOCIATION               T3
# 4  10556103  GENETIC RESEARCH INSTITUTE OF THE DESERT               T3
#
#         AFFILIATION CLASSIFICATION      USE_CASE  ORGANIZATION  STATUS  \
# 0       Independent          C1000    ProductDev   Association       1
# 1       Independent          C2000  Preservation  Co-operative       1
# 2  CompanySponsored          C3000    ProductDev   Association       1
# 3  CompanySponsored          C2000  Preservation         Trust       1
# 4       Independent          C1000     Heathcare         Trust       1
#
#       INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL
# 0              0                      N     5000              1
# 1         1-9999                      N   108590              1
# 2              0                      N     5000              0
# 3    10000-24999                      N     6692              1
# 4  100000-499999                      N   142590              1

# %%
# Drop the non-beneficial ID columns, 'EIN' and 'NAME'.
application_df.drop(columns=['EIN', 'NAME'], inplace=True)

# %%
# Determine the number of unique values in each column.
unique_counts = application_df.nunique()
print(unique_counts)
# Out:
# APPLICATION_TYPE            17
# AFFILIATION                  6
# CLASSIFICATION              71
# USE_CASE                     5
# ORGANIZATION                 4
# STATUS                       2
# INCOME_AMT                   9
# SPECIAL_CONSIDERATIONS       2
# ASK_AMT                   8747
# IS_SUCCESSFUL                2
# dtype: int64

# %%
# Look at APPLICATION_TYPE value counts for binning
print(application_df['APPLICATION_TYPE'].value_counts())
# Out:
# T3     27037
# T4      1542
# T6      1216
# T5      1173
# T19     1065
# T8       737
# T7       725
# T10      528
# T9       156
# T13       66
# T12       27
# T2        16
# T25        3
# T14        3
# T29        2
# T15        2
# T17        1
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Choose a cutoff value and create a list of application types to be replaced
# use the variable name `application_types_to_replace`
app_type_counts = application_df['APPLICATION_TYPE'].value_counts()
application_types_to_replace = list(app_type_counts[app_type_counts < 500].index)
print(application_types_to_replace)

# Replace in dataframe
for app in application_types_to_replace:
    application_df['APPLICATION_TYPE'] = application_df['APPLICATION_TYPE'].replace(app,"Other")

# Check to make sure binning was successful
application_df['APPLICATION_TYPE'].value_counts()
# Out:
# ['T9', 'T13', 'T12', 'T2', 'T25', 'T14', 'T29', 'T15', 'T17']
# T3       27037
# T4        1542
# T6        1216
# T5        1173
# T19       1065
# T8         737
# T7         725
# T10        528
# Other      276
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Look at CLASSIFICATION value counts for binning
classification_counts = application_df['CLASSIFICATION'].value_counts()
print(classification_counts)
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
#          ...
# C4120        1
# C8210        1
# C2561        1
# C4500        1
# C2150        1
# Name: CLASSIFICATION, Length: 71, dtype: int64

# %%
# You may find it helpful to look at CLASSIFICATION value counts >1
classification_counts = application_df['CLASSIFICATION'].value_counts()
classification_counts_greater_than_one = classification_counts[classification_counts > 1]
print(classification_counts_greater_than_one)
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# C7000      777
# C1700      287
# C4000      194
# C5000      116
# C1270      114
# C2700      104
# C2800       95
# C7100       75
# C1300       58
# C1280       50
# C1230       36
# C1400       34
# C7200       32
# C2300       32
# C1240       30
# C8000       20
# C7120       18
# C1500       16
# C1800       15
# C6000       15
# C1250       14
# C8200       11
# C1238       10
# C1278       10
# C1235        9
# C1237        9
# C7210        7
# C2400        6
# C1720        6
# C4100        6
# C1257        5
# C1600        5
# C1260        3
# C2710        3
# C0           3
# C3200        2
# C1234        2
# C1246        2
# C1267        2
# C1256        2
# Name: CLASSIFICATION, dtype: int64

# %%
# Choose a cutoff value and create a list of classifications to be replaced
# use the variable name `classifications_to_replace`
classifications_to_replace = list(classification_counts[classification_counts < 1000].index)
print(classifications_to_replace)

# Replace in dataframe
for cls in classifications_to_replace:
    application_df['CLASSIFICATION'] = application_df['CLASSIFICATION'].replace(cls,"Other")
    
# Check to make sure binning was successful
application_df['CLASSIFICATION'].value_counts()
# Out:
# ['C7000', 'C1700', 'C4000', 'C5000', 'C1270', 'C2700', 'C2800', 'C7100', 'C1300', 'C1280', 'C1230', 'C1400', 'C7200', 'C2300', 'C1240', 'C8000', 'C7120', 'C1500', 'C1800', 'C6000', 'C1250', 'C8200', 'C1238', 'C1278', 'C1235', 'C1237', 'C7210', 'C2400', 'C1720', 'C4100', 'C1257', 'C1600', 'C1260', 'C2710', 'C0', 'C3200', 'C1234', 'C1246', 'C1267', 'C1256', 'C2190', 'C4200', 'C2600', 'C5200', 'C1370', 'C1248', 'C6100', 'C1820', 'C1900', 'C1236', 'C3700', 'C2570', 'C1580', 'C1245', 'C2500', 'C1570', 'C1283', 'C2380', 'C1732', 'C1728', 'C2170', 'C4120', 'C8210', 'C2561', 'C4500', 'C2150']
# C1000    17326
# C2000     6074
# C1200     4837
# Other     2261
# C3000     1918
# C2100     1883
# Name: CLASSIFICATION, dtype: int64

# %%
# Convert categorical data to numeric with `pd.get_dummies`
# create a list of columns to encode
cat_cols = ['APPLICATION_TYPE', 'AFFILIATION', 'CLASSIFICATION', 'USE_CASE', 'ORGANIZATION', 'INCOME_AMT', 'SPECIAL_CONSIDERATIONS']

# use pd.get_dummies to encode categorical variables
encoded_df = pd.get_dummies(application_df, columns=cat_cols)
encoded_df.shape
# Out:
# (34299, 44)

# %%
# Split our preprocessed data into our features and target arrays
X = encoded_df.drop("IS_SUCCESSFUL", axis=1).values
y = encoded_df["IS_SUCCESSFUL"].values

# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
from tensorflow.keras.layers import Dense

nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(Dense(units=80, activation='relu', input_dim=43))

# Second hidden layer
nn.add(Dense(units=30, activation='relu'))

# Output layer
nn.add(Dense(units=1, activation='sigmoid'))

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 80)                3520
#
#  dense_1 (Dense)             (None, 30)                2430
#
#  dense_2 (Dense)             (None, 1)                 31
#
# =================================================================
# Total params: 5,981
# Trainable params: 5,981
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
nn.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %% [markdown]
# ## Optimisation 1 - Altering the Number of Epochs

# %%
# Train the model
nn.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Define the checkpoint path and filename
checkpoint_path = "model_weights/checkpoint_weights.{epoch:02d}.h5"

# Create a callback that saves the model's weights every five epochs
checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_path,
    save_weights_only=True,
    save_freq=5 * len(X_train_scaled),
    verbose=1)

# Train the model with the checkpoint callback
fit_model = nn.fit(X_train_scaled, y_train, epochs=100, callbacks=[checkpoint_callback])

# Evaluate the model using the test data
evaluation = nn.evaluate(X_test_scaled, y_test, verbose=2)
print(f"Loss: {evaluation[0]}, Accuracy: {evaluation[1]}")
# Out:
# Epoch 1/100
# 804/804 [==============================] - 4s 3ms/step - loss: 0.5670 - accuracy: 0.7220
# Epoch 2/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5536 - accuracy: 0.7306
# Epoch 3/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5516 - accuracy: 0.7290
# Epoch 4/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5505 - accuracy: 0.7313
# Epoch 5/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5489 - accuracy: 0.7327
# Epoch 6/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5474 - accuracy: 0.7322
# Epoch 7/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5483 - accuracy: 0.7313
# Epoch 8/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5465 - accuracy: 0.7328
# Epoch 9/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5460 - accuracy: 0.7314
# Epoch 10/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5455 - accuracy: 0.7329
# Epoch 11/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5455 - accuracy: 0.7324
# Epoch 12/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5444 - accuracy: 0.7334
# Epoch 13/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5443 - accuracy: 0.7340
# Epoch 14/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5441 - accuracy: 0.7361
# Epoch 15/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5441 - accuracy: 0.7330
# Epoch 16/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5437 - accuracy: 0.7348
# Epoch 17/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5433 - accuracy: 0.7344
# Epoch 18/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5426 - accuracy: 0.7350
# Epoch 19/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5430 - accuracy: 0.7354
# Epoch 20/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5427 - accuracy: 0.7353
# Epoch 21/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5425 - accuracy: 0.7353
# Epoch 22/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5424 - accuracy: 0.7355
# Epoch 23/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5419 - accuracy: 0.7358
# Epoch 24/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5419 - accuracy: 0.7364
# Epoch 25/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5415 - accuracy: 0.7364
# Epoch 26/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5412 - accuracy: 0.7365
# Epoch 27/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5408 - accuracy: 0.7368
# Epoch 28/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5405 - accuracy: 0.7368
# Epoch 29/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5399 - accuracy: 0.7369
# Epoch 30/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5403 - accuracy: 0.7368
# Epoch 31/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5406 - accuracy: 0.7373
# Epoch 32/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5399 - accuracy: 0.7385
# Epoch 33/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5400 - accuracy: 0.7372
# Epoch 34/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5394 - accuracy: 0.7367
# Epoch 35/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5393 - accuracy: 0.7383
# Epoch 36/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5394 - accuracy: 0.7373
# Epoch 37/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5388 - accuracy: 0.7376
# Epoch 38/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5391 - accuracy: 0.7381
# Epoch 39/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5390 - accuracy: 0.7377
# Epoch 40/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5382 - accuracy: 0.7377
# Epoch 41/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5388 - accuracy: 0.7377
# Epoch 42/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5389 - accuracy: 0.7367
# Epoch 43/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5384 - accuracy: 0.7389
# Epoch 44/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5379 - accuracy: 0.7379
# Epoch 45/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5379 - accuracy: 0.7382
# Epoch 46/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5380 - accuracy: 0.7377
# Epoch 47/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5376 - accuracy: 0.7380
# Epoch 48/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5377 - accuracy: 0.7388
# Epoch 49/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5378 - accuracy: 0.7389
# Epoch 50/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5371 - accuracy: 0.7382
# Epoch 51/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5372 - accuracy: 0.7382
# Epoch 52/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5373 - accuracy: 0.7389
# Epoch 53/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5380 - accuracy: 0.7386
# Epoch 54/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5373 - accuracy: 0.7389
# Epoch 55/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5371 - accuracy: 0.7378
# Epoch 56/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5368 - accuracy: 0.7380
# Epoch 57/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5372 - accuracy: 0.7398
# Epoch 58/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5363 - accuracy: 0.7379
# Epoch 59/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5369 - accuracy: 0.7383
# Epoch 60/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5366 - accuracy: 0.7383
# Epoch 61/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5366 - accuracy: 0.7383
# Epoch 62/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5370 - accuracy: 0.7384
# Epoch 63/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5366 - accuracy: 0.7395
# Epoch 64/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5365 - accuracy: 0.7385
# Epoch 65/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5365 - accuracy: 0.7389
# Epoch 66/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5359 - accuracy: 0.7391
# Epoch 67/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5361 - accuracy: 0.7388
# Epoch 68/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5361 - accuracy: 0.7390
# Epoch 69/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5359 - accuracy: 0.7388
# Epoch 70/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5361 - accuracy: 0.7383
# Epoch 71/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5362 - accuracy: 0.7383
# Epoch 72/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5357 - accuracy: 0.7396
# Epoch 73/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5361 - accuracy: 0.7385
# Epoch 74/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5355 - accuracy: 0.7394
# Epoch 75/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5354 - accuracy: 0.7403
# Epoch 76/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5358 - accuracy: 0.7387
# Epoch 77/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5357 - accuracy: 0.7396
# Epoch 78/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5353 - accuracy: 0.7380
# Epoch 79/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5354 - accuracy: 0.7399
# Epoch 80/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5360 - accuracy: 0.7386
# Epoch 81/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5350 - accuracy: 0.7389
# Epoch 82/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5356 - accuracy: 0.7388
# Epoch 83/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5351 - accuracy: 0.7387
# Epoch 84/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5354 - accuracy: 0.7393
# Epoch 85/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5351 - accuracy: 0.7379
# Epoch 86/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5351 - accuracy: 0.7395
# Epoch 87/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5355 - accuracy: 0.7388
# Epoch 88/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5362 - accuracy: 0.7398
# Epoch 89/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5350 - accuracy: 0.7395
# Epoch 90/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5350 - accuracy: 0.7393
# Epoch 91/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5349 - accuracy: 0.7393
# Epoch 92/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5348 - accuracy: 0.7391
# Epoch 93/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5347 - accuracy: 0.7395
# Epoch 94/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5347 - accuracy: 0.7388
# Epoch 95/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5344 - accuracy: 0.7398
# Epoch 96/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5349 - accuracy: 0.7399
# Epoch 97/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5350 - accuracy: 0.7392
# Epoch 98/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5366 - accuracy: 0.7392
# Epoch 99/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5350 - accuracy: 0.7394
# Epoch 100/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5348 - accuracy: 0.7400
# 268/268 - 0s - loss: 0.5634 - accuracy: 0.7306 - 371ms/epoch - 1ms/step
# Loss: 0.563425600528717, Accuracy: 0.7306122183799744

# %%
# Train the model
nn.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Define the checkpoint path and filename
checkpoint_path = "model_weights/checkpoint_weights.{epoch:02d}.h5"

# Create a callback that saves the model's weights every five epochs
checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_path,
    save_weights_only=True,
    save_freq=5 * len(X_train_scaled),
    verbose=1)

# Train the model with the checkpoint callback
fit_model = nn.fit(X_train_scaled, y_train, epochs=25, callbacks=[checkpoint_callback])

# Evaluate the model using the test data
evaluation = nn.evaluate(X_test_scaled, y_test, verbose=2)
print(f"Loss: {evaluation[0]}, Accuracy: {evaluation[1]}")
# Out:
# Epoch 1/25
# 804/804 [==============================] - 2s 1ms/step - loss: 0.5356 - accuracy: 0.7395
# Epoch 2/25
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5343 - accuracy: 0.7398
# Epoch 3/25
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5343 - accuracy: 0.7394
# Epoch 4/25
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5338 - accuracy: 0.7401
# Epoch 5/25
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5342 - accuracy: 0.7392
# Epoch 6/25
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5342 - accuracy: 0.7398
# Epoch 7/25
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5343 - accuracy: 0.7404
# Epoch 8/25
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5344 - accuracy: 0.7394
# Epoch 9/25
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5338 - accuracy: 0.7403
# Epoch 10/25
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5345 - accuracy: 0.7397
# Epoch 11/25
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5338 - accuracy: 0.7403
# Epoch 12/25
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5338 - accuracy: 0.7388
# Epoch 13/25
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5341 - accuracy: 0.7404
# Epoch 14/25
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5342 - accuracy: 0.7402
# Epoch 15/25
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5339 - accuracy: 0.7405
# Epoch 16/25
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5339 - accuracy: 0.7399
# Epoch 17/25
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5339 - accuracy: 0.7400
# Epoch 18/25
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5348 - accuracy: 0.7398
# Epoch 19/25
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5339 - accuracy: 0.7398
# Epoch 20/25
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5338 - accuracy: 0.7402
# Epoch 21/25
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5340 - accuracy: 0.7393
# Epoch 22/25
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5335 - accuracy: 0.7400
# Epoch 23/25
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5337 - accuracy: 0.7401
# Epoch 24/25
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5336 - accuracy: 0.7405
# Epoch 25/25
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5339 - accuracy: 0.7395
# 268/268 - 0s - loss: 0.5671 - accuracy: 0.7290 - 347ms/epoch - 1ms/step
# Loss: 0.5671390891075134, Accuracy: 0.7289795875549316

# %%
# Train the model
nn.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Define the checkpoint path and filename
checkpoint_path = "model_weights/checkpoint_weights.{epoch:02d}.h5"

# Create a callback that saves the model's weights every five epochs
checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_path,
    save_weights_only=True,
    save_freq=5 * len(X_train_scaled),
    verbose=1)

# Train the model with the checkpoint callback
fit_model = nn.fit(X_train_scaled, y_train, epochs=75, callbacks=[checkpoint_callback])

# Evaluate the model using the test data
evaluation = nn.evaluate(X_test_scaled, y_test, verbose=2)
print(f"Loss: {evaluation[0]}, Accuracy: {evaluation[1]}")
# Out:
# Epoch 1/75
# 804/804 [==============================] - 2s 1ms/step - loss: 0.5339 - accuracy: 0.7414
# Epoch 2/75
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5335 - accuracy: 0.7406
# Epoch 3/75
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5339 - accuracy: 0.7400
# Epoch 4/75
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5348 - accuracy: 0.7399
# Epoch 5/75
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5332 - accuracy: 0.7403
# Epoch 6/75
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5334 - accuracy: 0.7398
# Epoch 7/75
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5339 - accuracy: 0.7403
# Epoch 8/75
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5330 - accuracy: 0.7398
# Epoch 9/75
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5343 - accuracy: 0.7407
# Epoch 10/75
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5336 - accuracy: 0.7404
# Epoch 11/75
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5331 - accuracy: 0.7401
# Epoch 12/75
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5330 - accuracy: 0.7405
# Epoch 13/75
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5333 - accuracy: 0.7404
# Epoch 14/75
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5335 - accuracy: 0.7408
# Epoch 15/75
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5337 - accuracy: 0.7404
# Epoch 16/75
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5333 - accuracy: 0.7402
# Epoch 17/75
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5331 - accuracy: 0.7400
# Epoch 18/75
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5330 - accuracy: 0.7403
# Epoch 19/75
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5330 - accuracy: 0.7406
# Epoch 20/75
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5334 - accuracy: 0.7397
# Epoch 21/75
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5334 - accuracy: 0.7399
# Epoch 22/75
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5330 - accuracy: 0.7407
# Epoch 23/75
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5332 - accuracy: 0.7400
# Epoch 24/75
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5326 - accuracy: 0.7404
# Epoch 25/75
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5327 - accuracy: 0.7409
# Epoch 26/75
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5336 - accuracy: 0.7399
# Epoch 27/75
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5329 - accuracy: 0.7406
# Epoch 28/75
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5331 - accuracy: 0.7401
# Epoch 29/75
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5332 - accuracy: 0.7411
# Epoch 30/75
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5327 - accuracy: 0.7408
# Epoch 31/75
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5327 - accuracy: 0.7408
# Epoch 32/75
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5328 - accuracy: 0.7402
# Epoch 33/75
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5324 - accuracy: 0.7410
# Epoch 34/75
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5331 - accuracy: 0.7408
# Epoch 35/75
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5328 - accuracy: 0.7407
# Epoch 36/75
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5331 - accuracy: 0.7407
# Epoch 37/75
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5332 - accuracy: 0.7409
# Epoch 38/75
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5325 - accuracy: 0.7404
# Epoch 39/75
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5325 - accuracy: 0.7406
# Epoch 40/75
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5325 - accuracy: 0.7414
# Epoch 41/75
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5328 - accuracy: 0.7406
# Epoch 42/75
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5331 - accuracy: 0.7406
# Epoch 43/75
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5329 - accuracy: 0.7410
# Epoch 44/75
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5330 - accuracy: 0.7404
# Epoch 45/75
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5323 - accuracy: 0.7409
# Epoch 46/75
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5340 - accuracy: 0.7409
# Epoch 47/75
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5325 - accuracy: 0.7406
# Epoch 48/75
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5323 - accuracy: 0.7409
# Epoch 49/75
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5324 - accuracy: 0.7410
# Epoch 50/75
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5323 - accuracy: 0.7406
# Epoch 51/75
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5323 - accuracy: 0.7397
# Epoch 52/75
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5324 - accuracy: 0.7404
# Epoch 53/75
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5323 - accuracy: 0.7407
# Epoch 54/75
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5325 - accuracy: 0.7402
# Epoch 55/75
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5325 - accuracy: 0.7409
# Epoch 56/75
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5324 - accuracy: 0.7410
# Epoch 57/75
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5320 - accuracy: 0.7403
# Epoch 58/75
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5321 - accuracy: 0.7409
# Epoch 59/75
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5326 - accuracy: 0.7406
# Epoch 60/75
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5320 - accuracy: 0.7406
# Epoch 61/75
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5321 - accuracy: 0.7411
# Epoch 62/75
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5322 - accuracy: 0.7408
# Epoch 63/75
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5324 - accuracy: 0.7399
# Epoch 64/75
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5318 - accuracy: 0.7402
# Epoch 65/75
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5329 - accuracy: 0.7413
# Epoch 66/75
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5319 - accuracy: 0.7410
# Epoch 67/75
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5322 - accuracy: 0.7414
# Epoch 68/75
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5320 - accuracy: 0.7406
# Epoch 69/75
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5322 - accuracy: 0.7408
# Epoch 70/75
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5322 - accuracy: 0.7410
# Epoch 71/75
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5319 - accuracy: 0.7403
# Epoch 72/75
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5324 - accuracy: 0.7413
# Epoch 73/75
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5320 - accuracy: 0.7411
# Epoch 74/75
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5320 - accuracy: 0.7415
# Epoch 75/75
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5320 - accuracy: 0.7406
# 268/268 - 0s - loss: 0.5792 - accuracy: 0.7298 - 466ms/epoch - 2ms/step
# Loss: 0.5791715979576111, Accuracy: 0.7297959327697754

# %%
# Train the model
nn.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Define the checkpoint path and filename
checkpoint_path = "model_weights/checkpoint_weights.{epoch:02d}.h5"

# Create a callback that saves the model's weights every five epochs
checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_path,
    save_weights_only=True,
    save_freq=5 * len(X_train_scaled),
    verbose=1)

# Train the model with the checkpoint callback
fit_model = nn.fit(X_train_scaled, y_train, epochs=110, callbacks=[checkpoint_callback])

# Evaluate the model using the test data
evaluation = nn.evaluate(X_test_scaled, y_test, verbose=2)
print(f"Loss: {evaluation[0]}, Accuracy: {evaluation[1]}")
# Out:
# Epoch 1/110
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5323 - accuracy: 0.7409
# Epoch 2/110
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5326 - accuracy: 0.7409
# Epoch 3/110
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5322 - accuracy: 0.7408
# Epoch 4/110
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5314 - accuracy: 0.7410
# Epoch 5/110
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5318 - accuracy: 0.7409
# Epoch 6/110
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5320 - accuracy: 0.7409
# Epoch 7/110
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5319 - accuracy: 0.7399
# Epoch 8/110
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5317 - accuracy: 0.7409
# Epoch 9/110
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5320 - accuracy: 0.7402
# Epoch 10/110
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5315 - accuracy: 0.7412
# Epoch 11/110
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5315 - accuracy: 0.7414
# Epoch 12/110
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5314 - accuracy: 0.7415
# Epoch 13/110
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5316 - accuracy: 0.7401
# Epoch 14/110
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5314 - accuracy: 0.7410
# Epoch 15/110
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5317 - accuracy: 0.7410
# Epoch 16/110
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5318 - accuracy: 0.7411
# Epoch 17/110
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5315 - accuracy: 0.7410
# Epoch 18/110
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5317 - accuracy: 0.7406
# Epoch 19/110
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5316 - accuracy: 0.7416
# Epoch 20/110
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5313 - accuracy: 0.7406
# Epoch 21/110
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5314 - accuracy: 0.7408
# Epoch 22/110
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5318 - accuracy: 0.7402
# Epoch 23/110
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5314 - accuracy: 0.7408
# Epoch 24/110
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5313 - accuracy: 0.7409
# Epoch 25/110
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5312 - accuracy: 0.7404
# Epoch 26/110
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5319 - accuracy: 0.7410
# Epoch 27/110
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5316 - accuracy: 0.7413
# Epoch 28/110
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5313 - accuracy: 0.7408
# Epoch 29/110
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5310 - accuracy: 0.7408
# Epoch 30/110
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5318 - accuracy: 0.7412
# Epoch 31/110
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5318 - accuracy: 0.7409
# Epoch 32/110
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5310 - accuracy: 0.7409
# Epoch 33/110
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5317 - accuracy: 0.7410
# Epoch 34/110
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5315 - accuracy: 0.7412
# Epoch 35/110
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5310 - accuracy: 0.7409
# Epoch 36/110
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5318 - accuracy: 0.7407
# Epoch 37/110
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5308 - accuracy: 0.7416
# Epoch 38/110
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5311 - accuracy: 0.7412
# Epoch 39/110
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5310 - accuracy: 0.7412
# Epoch 40/110
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5319 - accuracy: 0.7411
# Epoch 41/110
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5322 - accuracy: 0.7409
# Epoch 42/110
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5311 - accuracy: 0.7415
# Epoch 43/110
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5310 - accuracy: 0.7405
# Epoch 44/110
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5308 - accuracy: 0.7409
# Epoch 45/110
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5314 - accuracy: 0.7416
# Epoch 46/110
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5311 - accuracy: 0.7415
# Epoch 47/110
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5311 - accuracy: 0.7416
# Epoch 48/110
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5307 - accuracy: 0.7418
# Epoch 49/110
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5310 - accuracy: 0.7415
# Epoch 50/110
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5316 - accuracy: 0.7411
# Epoch 51/110
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5307 - accuracy: 0.7413
# Epoch 52/110
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5316 - accuracy: 0.7407
# Epoch 53/110
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5313 - accuracy: 0.7411
# Epoch 54/110
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5327 - accuracy: 0.7415
# Epoch 55/110
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5316 - accuracy: 0.7408
# Epoch 56/110
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5309 - accuracy: 0.7414
# Epoch 57/110
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5311 - accuracy: 0.7415
# Epoch 58/110
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5314 - accuracy: 0.7413
# Epoch 59/110
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5310 - accuracy: 0.7413
# Epoch 60/110
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5307 - accuracy: 0.7416
# Epoch 61/110
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5306 - accuracy: 0.7418
# Epoch 62/110
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5310 - accuracy: 0.7412
# Epoch 63/110
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5312 - accuracy: 0.7420
# Epoch 64/110
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5308 - accuracy: 0.7413
# Epoch 65/110
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5310 - accuracy: 0.7411
# Epoch 66/110
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5307 - accuracy: 0.7416
# Epoch 67/110
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5307 - accuracy: 0.7415
# Epoch 68/110
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5315 - accuracy: 0.7413
# Epoch 69/110
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5307 - accuracy: 0.7415
# Epoch 70/110
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5339 - accuracy: 0.7418
# Epoch 71/110
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5318 - accuracy: 0.7412
# Epoch 72/110
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5312 - accuracy: 0.7413
# Epoch 73/110
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5308 - accuracy: 0.7418
# Epoch 74/110
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5307 - accuracy: 0.7413
# Epoch 75/110
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5304 - accuracy: 0.7412
# Epoch 76/110
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5315 - accuracy: 0.7411
# Epoch 77/110
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5310 - accuracy: 0.7413
# Epoch 78/110
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5306 - accuracy: 0.7411
# Epoch 79/110
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5307 - accuracy: 0.7415
# Epoch 80/110
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5310 - accuracy: 0.7411
# Epoch 81/110
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5311 - accuracy: 0.7413
# Epoch 82/110
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5306 - accuracy: 0.7414
# Epoch 83/110
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5309 - accuracy: 0.7416
# Epoch 84/110
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5306 - accuracy: 0.7411
# Epoch 85/110
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5305 - accuracy: 0.7407
# Epoch 86/110
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5309 - accuracy: 0.7409
# Epoch 87/110
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5313 - accuracy: 0.7417
# Epoch 88/110
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5312 - accuracy: 0.7411
# Epoch 89/110
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5308 - accuracy: 0.7411
# Epoch 90/110
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5306 - accuracy: 0.7416
# Epoch 91/110
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5310 - accuracy: 0.7413
# Epoch 92/110
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5320 - accuracy: 0.7413
# Epoch 93/110
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5308 - accuracy: 0.7420
# Epoch 94/110
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5302 - accuracy: 0.7415
# Epoch 95/110
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5307 - accuracy: 0.7417
# Epoch 96/110
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5305 - accuracy: 0.7411
# Epoch 97/110
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5323 - accuracy: 0.7414
# Epoch 98/110
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5310 - accuracy: 0.7421
# Epoch 99/110
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5303 - accuracy: 0.7416
# Epoch 100/110
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5300 - accuracy: 0.7413
# Epoch 101/110
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5315 - accuracy: 0.7414
# Epoch 102/110
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5336 - accuracy: 0.7415
# Epoch 103/110
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5312 - accuracy: 0.7419
# Epoch 104/110
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5305 - accuracy: 0.7413
# Epoch 105/110
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5312 - accuracy: 0.7413
# Epoch 106/110
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5305 - accuracy: 0.7418
# Epoch 107/110
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5304 - accuracy: 0.7414
# Epoch 108/110
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5303 - accuracy: 0.7416
# Epoch 109/110
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5313 - accuracy: 0.7419
# Epoch 110/110
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5304 - accuracy: 0.7421
# 268/268 - 0s - loss: 0.5944 - accuracy: 0.7297 - 487ms/epoch - 2ms/step
# Loss: 0.5943798422813416, Accuracy: 0.72967928647995

# %% [markdown]
# It is recommended to train the model with 100 epochs, as this resulted in the best performance on the test data.

# %% [markdown]
# ## Optimisation 2 - Altering the Optimizer

# %%
# Train the model
nn.compile(optimizer='SGD', loss='binary_crossentropy', metrics=['accuracy'])

# Define the checkpoint path and filename
checkpoint_path = "model_weights/checkpoint_weights.{epoch:02d}.h5"

# Create a callback that saves the model's weights every five epochs
checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_path,
    save_weights_only=True,
    save_freq=5 * len(X_train_scaled),
    verbose=1)

# Train the model with the checkpoint callback
fit_model = nn.fit(X_train_scaled, y_train, epochs=100, callbacks=[checkpoint_callback])

# Evaluate the model using the test data
evaluation = nn.evaluate(X_test_scaled, y_test, verbose=2)
print(f"Loss: {evaluation[0]}, Accuracy: {evaluation[1]}")
# Out:
# Epoch 1/100
# 804/804 [==============================] - 2s 1ms/step - loss: 0.5286 - accuracy: 0.7418
# Epoch 2/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5286 - accuracy: 0.7425
# Epoch 3/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5285 - accuracy: 0.7427
# Epoch 4/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5285 - accuracy: 0.7426
# Epoch 5/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5282 - accuracy: 0.7426
# Epoch 6/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5284 - accuracy: 0.7423
# Epoch 7/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5283 - accuracy: 0.7428
# Epoch 8/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5282 - accuracy: 0.7425
# Epoch 9/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5284 - accuracy: 0.7423
# Epoch 10/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5280 - accuracy: 0.7422
# Epoch 11/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5280 - accuracy: 0.7426
# Epoch 12/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5281 - accuracy: 0.7425
# Epoch 13/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5283 - accuracy: 0.7424
# Epoch 14/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5282 - accuracy: 0.7425
# Epoch 15/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5279 - accuracy: 0.7428
# Epoch 16/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5281 - accuracy: 0.7427
# Epoch 17/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5280 - accuracy: 0.7428
# Epoch 18/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5281 - accuracy: 0.7425
# Epoch 19/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5280 - accuracy: 0.7429
# Epoch 20/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5281 - accuracy: 0.7422
# Epoch 21/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5281 - accuracy: 0.7425
# Epoch 22/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5281 - accuracy: 0.7430
# Epoch 23/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5280 - accuracy: 0.7424
# Epoch 24/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5277 - accuracy: 0.7424
# Epoch 25/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5280 - accuracy: 0.7426
# Epoch 26/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5277 - accuracy: 0.7429
# Epoch 27/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5281 - accuracy: 0.7425
# Epoch 28/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5279 - accuracy: 0.7428
# Epoch 29/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5278 - accuracy: 0.7421
# Epoch 30/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5279 - accuracy: 0.7427
# Epoch 31/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5281 - accuracy: 0.7423
# Epoch 32/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5281 - accuracy: 0.7425
# Epoch 33/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5279 - accuracy: 0.7425
# Epoch 34/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5280 - accuracy: 0.7423
# Epoch 35/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5281 - accuracy: 0.7425
# Epoch 36/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5279 - accuracy: 0.7426
# Epoch 37/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5279 - accuracy: 0.7425
# Epoch 38/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5279 - accuracy: 0.7424
# Epoch 39/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5276 - accuracy: 0.7428
# Epoch 40/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5278 - accuracy: 0.7427
# Epoch 41/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5278 - accuracy: 0.7425
# Epoch 42/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5277 - accuracy: 0.7426
# Epoch 43/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5277 - accuracy: 0.7424
# Epoch 44/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5279 - accuracy: 0.7427
# Epoch 45/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5279 - accuracy: 0.7427
# Epoch 46/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5279 - accuracy: 0.7424
# Epoch 47/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5278 - accuracy: 0.7423
# Epoch 48/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5279 - accuracy: 0.7425
# Epoch 49/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5278 - accuracy: 0.7427
# Epoch 50/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5277 - accuracy: 0.7426
# Epoch 51/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5277 - accuracy: 0.7428
# Epoch 52/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5278 - accuracy: 0.7425
# Epoch 53/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5278 - accuracy: 0.7427
# Epoch 54/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5279 - accuracy: 0.7425
# Epoch 55/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5279 - accuracy: 0.7425
# Epoch 56/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5277 - accuracy: 0.7425
# Epoch 57/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5278 - accuracy: 0.7425
# Epoch 58/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5279 - accuracy: 0.7423
# Epoch 59/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5278 - accuracy: 0.7427
# Epoch 60/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5277 - accuracy: 0.7429
# Epoch 61/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5277 - accuracy: 0.7423
# Epoch 62/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5277 - accuracy: 0.7428
# Epoch 63/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5277 - accuracy: 0.7427
# Epoch 64/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5277 - accuracy: 0.7424
# Epoch 65/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5278 - accuracy: 0.7428
# Epoch 66/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5278 - accuracy: 0.7430
# Epoch 67/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5276 - accuracy: 0.7428
# Epoch 68/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5277 - accuracy: 0.7427
# Epoch 69/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5275 - accuracy: 0.7425
# Epoch 70/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5278 - accuracy: 0.7425
# Epoch 71/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5276 - accuracy: 0.7428
# Epoch 72/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5276 - accuracy: 0.7425
# Epoch 73/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5278 - accuracy: 0.7429
# Epoch 74/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5278 - accuracy: 0.7425
# Epoch 75/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5275 - accuracy: 0.7429
# Epoch 76/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5276 - accuracy: 0.7426
# Epoch 77/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5276 - accuracy: 0.7428
# Epoch 78/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5276 - accuracy: 0.7430
# Epoch 79/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5275 - accuracy: 0.7426
# Epoch 80/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5271 - accuracy: 0.7430
# Epoch 81/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5278 - accuracy: 0.7427
# Epoch 82/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5277 - accuracy: 0.7432
# Epoch 83/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5278 - accuracy: 0.7426
# Epoch 84/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5276 - accuracy: 0.7425
# Epoch 85/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5277 - accuracy: 0.7428
# Epoch 86/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5275 - accuracy: 0.7427
# Epoch 87/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5277 - accuracy: 0.7425
# Epoch 88/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5276 - accuracy: 0.7426
# Epoch 89/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5277 - accuracy: 0.7428
# Epoch 90/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5275 - accuracy: 0.7430
# Epoch 91/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5276 - accuracy: 0.7427
# Epoch 92/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5278 - accuracy: 0.7423
# Epoch 93/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5276 - accuracy: 0.7428
# Epoch 94/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5277 - accuracy: 0.7428
# Epoch 95/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5276 - accuracy: 0.7425
# Epoch 96/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5275 - accuracy: 0.7425
# Epoch 97/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5276 - accuracy: 0.7425
# Epoch 98/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5276 - accuracy: 0.7429
# Epoch 99/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5275 - accuracy: 0.7428
# Epoch 100/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5275 - accuracy: 0.7429
# 268/268 - 0s - loss: 0.6035 - accuracy: 0.7289 - 482ms/epoch - 2ms/step
# Loss: 0.6034960150718689, Accuracy: 0.728863000869751

# %%
# Train the model
nn.compile(optimizer='Adagrad', loss='binary_crossentropy', metrics=['accuracy'])

# Define the checkpoint path and filename
checkpoint_path = "model_weights/checkpoint_weights.{epoch:02d}.h5"

# Create a callback that saves the model's weights every five epochs
checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_path,
    save_weights_only=True,
    save_freq=5 * len(X_train_scaled),
    verbose=1)

# Train the model with the checkpoint callback
fit_model = nn.fit(X_train_scaled, y_train, epochs=100, callbacks=[checkpoint_callback])

# Evaluate the model using the test data
evaluation = nn.evaluate(X_test_scaled, y_test, verbose=2)
print(f"Loss: {evaluation[0]}, Accuracy: {evaluation[1]}")
# Out:
# Epoch 1/100
# 804/804 [==============================] - 2s 1ms/step - loss: 0.5270 - accuracy: 0.7428
# Epoch 2/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5268 - accuracy: 0.7428
# Epoch 3/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5268 - accuracy: 0.7428
# Epoch 4/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5268 - accuracy: 0.7429
# Epoch 5/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5267 - accuracy: 0.7428
# Epoch 6/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5267 - accuracy: 0.7428
# Epoch 7/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5267 - accuracy: 0.7428
# Epoch 8/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5267 - accuracy: 0.7428
# Epoch 9/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5267 - accuracy: 0.7428
# Epoch 10/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5267 - accuracy: 0.7428
# Epoch 11/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5267 - accuracy: 0.7428
# Epoch 12/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5267 - accuracy: 0.7428
# Epoch 13/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5267 - accuracy: 0.7428
# Epoch 14/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5267 - accuracy: 0.7428
# Epoch 15/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5267 - accuracy: 0.7428
# Epoch 16/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5267 - accuracy: 0.7428
# Epoch 17/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5267 - accuracy: 0.7427
# Epoch 18/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5267 - accuracy: 0.7428
# Epoch 19/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5267 - accuracy: 0.7428
# Epoch 20/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5267 - accuracy: 0.7428
# Epoch 21/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5267 - accuracy: 0.7428
# Epoch 22/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5267 - accuracy: 0.7428
# Epoch 23/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5267 - accuracy: 0.7428
# Epoch 24/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5267 - accuracy: 0.7428
# Epoch 25/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5267 - accuracy: 0.7428
# Epoch 26/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5267 - accuracy: 0.7428
# Epoch 27/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5267 - accuracy: 0.7428
# Epoch 28/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5267 - accuracy: 0.7428
# Epoch 29/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5267 - accuracy: 0.7428
# Epoch 30/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5267 - accuracy: 0.7428
# Epoch 31/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5267 - accuracy: 0.7428
# Epoch 32/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5267 - accuracy: 0.7428
# Epoch 33/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5267 - accuracy: 0.7428
# Epoch 34/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5267 - accuracy: 0.7428
# Epoch 35/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5267 - accuracy: 0.7428
# Epoch 36/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5267 - accuracy: 0.7428
# Epoch 37/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5267 - accuracy: 0.7428
# Epoch 38/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5267 - accuracy: 0.7428
# Epoch 39/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5267 - accuracy: 0.7428
# Epoch 40/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5267 - accuracy: 0.7428
# Epoch 41/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5267 - accuracy: 0.7428
# Epoch 42/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5267 - accuracy: 0.7428
# Epoch 43/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5267 - accuracy: 0.7428
# Epoch 44/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5267 - accuracy: 0.7428
# Epoch 45/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5267 - accuracy: 0.7428
# Epoch 46/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5267 - accuracy: 0.7428
# Epoch 47/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5267 - accuracy: 0.7428
# Epoch 48/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5267 - accuracy: 0.7428
# Epoch 49/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5266 - accuracy: 0.7428
# Epoch 50/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5266 - accuracy: 0.7427
# Epoch 51/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5266 - accuracy: 0.7428
# Epoch 52/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5266 - accuracy: 0.7428
# Epoch 53/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5266 - accuracy: 0.7427
# Epoch 54/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5266 - accuracy: 0.7428
# Epoch 55/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5266 - accuracy: 0.7428
# Epoch 56/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5266 - accuracy: 0.7428
# Epoch 57/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5266 - accuracy: 0.7428
# Epoch 58/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5266 - accuracy: 0.7428
# Epoch 59/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5266 - accuracy: 0.7428
# Epoch 60/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5266 - accuracy: 0.7428
# Epoch 61/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5266 - accuracy: 0.7428
# Epoch 62/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5266 - accuracy: 0.7428
# Epoch 63/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5266 - accuracy: 0.7428
# Epoch 64/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5266 - accuracy: 0.7428
# Epoch 65/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5266 - accuracy: 0.7428
# Epoch 66/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5266 - accuracy: 0.7428
# Epoch 67/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5266 - accuracy: 0.7428
# Epoch 68/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5266 - accuracy: 0.7428
# Epoch 69/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5266 - accuracy: 0.7428
# Epoch 70/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5266 - accuracy: 0.7428
# Epoch 71/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5266 - accuracy: 0.7428
# Epoch 72/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5266 - accuracy: 0.7428
# Epoch 73/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5266 - accuracy: 0.7428
# Epoch 74/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5266 - accuracy: 0.7428
# Epoch 75/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5266 - accuracy: 0.7428
# Epoch 76/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5266 - accuracy: 0.7428
# Epoch 77/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5266 - accuracy: 0.7428
# Epoch 78/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5266 - accuracy: 0.7428
# Epoch 79/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5266 - accuracy: 0.7428
# Epoch 80/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5266 - accuracy: 0.7428
# Epoch 81/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5266 - accuracy: 0.7428
# Epoch 82/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5266 - accuracy: 0.7428
# Epoch 83/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5266 - accuracy: 0.7428
# Epoch 84/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5266 - accuracy: 0.7428
# Epoch 85/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5266 - accuracy: 0.7428
# Epoch 86/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5266 - accuracy: 0.7428
# Epoch 87/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5266 - accuracy: 0.7428
# Epoch 88/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5266 - accuracy: 0.7428
# Epoch 89/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5266 - accuracy: 0.7428
# Epoch 90/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5266 - accuracy: 0.7428
# Epoch 91/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5266 - accuracy: 0.7427
# Epoch 92/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5266 - accuracy: 0.7428
# Epoch 93/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5266 - accuracy: 0.7428
# Epoch 94/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5266 - accuracy: 0.7428
# Epoch 95/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5266 - accuracy: 0.7428
# Epoch 96/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5266 - accuracy: 0.7428
# Epoch 97/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5266 - accuracy: 0.7428
# Epoch 98/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5266 - accuracy: 0.7428
# Epoch 99/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5266 - accuracy: 0.7428
# Epoch 100/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5266 - accuracy: 0.7428
# 268/268 - 0s - loss: 0.6046 - accuracy: 0.7286 - 339ms/epoch - 1ms/step
# Loss: 0.6045528054237366, Accuracy: 0.7286297082901001

# %%
# Train the model
nn.compile(optimizer='RMSprop', loss='binary_crossentropy', metrics=['accuracy'])

# Define the checkpoint path and filename
checkpoint_path = "model_weights/checkpoint_weights.{epoch:02d}.h5"

# Create a callback that saves the model's weights every five epochs
checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_path,
    save_weights_only=True,
    save_freq=5 * len(X_train_scaled),
    verbose=1)

# Train the model with the checkpoint callback
fit_model = nn.fit(X_train_scaled, y_train, epochs=100, callbacks=[checkpoint_callback])

# Evaluate the model using the test data
evaluation = nn.evaluate(X_test_scaled, y_test, verbose=2)
print(f"Loss: {evaluation[0]}, Accuracy: {evaluation[1]}")
# Out:
# Epoch 1/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5314 - accuracy: 0.7421
# Epoch 2/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5342 - accuracy: 0.7412
# Epoch 3/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5347 - accuracy: 0.7409
# Epoch 4/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5368 - accuracy: 0.7406
# Epoch 5/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5382 - accuracy: 0.7405
# Epoch 6/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5385 - accuracy: 0.7400
# Epoch 7/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5392 - accuracy: 0.7401
# Epoch 8/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5421 - accuracy: 0.7408
# Epoch 9/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5428 - accuracy: 0.7403
# Epoch 10/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5410 - accuracy: 0.7402
# Epoch 11/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5425 - accuracy: 0.7393
# Epoch 12/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5427 - accuracy: 0.7394
# Epoch 13/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5421 - accuracy: 0.7397
# Epoch 14/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5414 - accuracy: 0.7403
# Epoch 15/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5433 - accuracy: 0.7392
# Epoch 16/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5423 - accuracy: 0.7397
# Epoch 17/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5417 - accuracy: 0.7397
# Epoch 18/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5427 - accuracy: 0.7387
# Epoch 19/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5427 - accuracy: 0.7395
# Epoch 20/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5423 - accuracy: 0.7393
# Epoch 21/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5426 - accuracy: 0.7396
# Epoch 22/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5432 - accuracy: 0.7386
# Epoch 23/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5438 - accuracy: 0.7378
# Epoch 24/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5433 - accuracy: 0.7391
# Epoch 25/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5438 - accuracy: 0.7397
# Epoch 26/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5448 - accuracy: 0.7376
# Epoch 27/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5439 - accuracy: 0.7379
# Epoch 28/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5443 - accuracy: 0.7378
# Epoch 29/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5438 - accuracy: 0.7386
# Epoch 30/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5425 - accuracy: 0.7386
# Epoch 31/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5442 - accuracy: 0.7384
# Epoch 32/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5429 - accuracy: 0.7386
# Epoch 33/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5427 - accuracy: 0.7391
# Epoch 34/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5424 - accuracy: 0.7397
# Epoch 35/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5437 - accuracy: 0.7388
# Epoch 36/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5432 - accuracy: 0.7388
# Epoch 37/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5435 - accuracy: 0.7382
# Epoch 38/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5437 - accuracy: 0.7378
# Epoch 39/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5433 - accuracy: 0.7389
# Epoch 40/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5433 - accuracy: 0.7381
# Epoch 41/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5429 - accuracy: 0.7383
# Epoch 42/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5426 - accuracy: 0.7382
# Epoch 43/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5429 - accuracy: 0.7375
# Epoch 44/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5428 - accuracy: 0.7390
# Epoch 45/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5424 - accuracy: 0.7388
# Epoch 46/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5432 - accuracy: 0.7381
# Epoch 47/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5434 - accuracy: 0.7375
# Epoch 48/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5433 - accuracy: 0.7383
# Epoch 49/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5429 - accuracy: 0.7383
# Epoch 50/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5433 - accuracy: 0.7375
# Epoch 51/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5428 - accuracy: 0.7379
# Epoch 52/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5423 - accuracy: 0.7384
# Epoch 53/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5427 - accuracy: 0.7379
# Epoch 54/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5421 - accuracy: 0.7370
# Epoch 55/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5430 - accuracy: 0.7391
# Epoch 56/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5443 - accuracy: 0.7382
# Epoch 57/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5432 - accuracy: 0.7386
# Epoch 58/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5427 - accuracy: 0.7379
# Epoch 59/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5433 - accuracy: 0.7380
# Epoch 60/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5431 - accuracy: 0.7390
# Epoch 61/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5426 - accuracy: 0.7381
# Epoch 62/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5427 - accuracy: 0.7380
# Epoch 63/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5426 - accuracy: 0.7381
# Epoch 64/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5424 - accuracy: 0.7379
# Epoch 65/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5432 - accuracy: 0.7374
# Epoch 66/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5431 - accuracy: 0.7379
# Epoch 67/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5435 - accuracy: 0.7381
# Epoch 68/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5429 - accuracy: 0.7371
# Epoch 69/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5431 - accuracy: 0.7380
# Epoch 70/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5428 - accuracy: 0.7381
# Epoch 71/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5428 - accuracy: 0.7371
# Epoch 72/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5427 - accuracy: 0.7375
# Epoch 73/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5427 - accuracy: 0.7386
# Epoch 74/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5431 - accuracy: 0.7393
# Epoch 75/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5426 - accuracy: 0.7372
# Epoch 76/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5427 - accuracy: 0.7381
# Epoch 77/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5430 - accuracy: 0.7379
# Epoch 78/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5421 - accuracy: 0.7380
# Epoch 79/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5425 - accuracy: 0.7386
# Epoch 80/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5426 - accuracy: 0.7383
# Epoch 81/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5427 - accuracy: 0.7381
# Epoch 82/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5432 - accuracy: 0.7381
# Epoch 83/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5430 - accuracy: 0.7374
# Epoch 84/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5432 - accuracy: 0.7377
# Epoch 85/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5423 - accuracy: 0.7385
# Epoch 86/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5423 - accuracy: 0.7386
# Epoch 87/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5427 - accuracy: 0.7387
# Epoch 88/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5428 - accuracy: 0.7380
# Epoch 89/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5422 - accuracy: 0.7395
# Epoch 90/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5427 - accuracy: 0.7389
# Epoch 91/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5421 - accuracy: 0.7385
# Epoch 92/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5428 - accuracy: 0.7393
# Epoch 93/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5425 - accuracy: 0.7392
# Epoch 94/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5424 - accuracy: 0.7390
# Epoch 95/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5423 - accuracy: 0.7387
# Epoch 96/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5425 - accuracy: 0.7392
# Epoch 97/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5418 - accuracy: 0.7384
# Epoch 98/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5423 - accuracy: 0.7395
# Epoch 99/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5421 - accuracy: 0.7383
# Epoch 100/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5422 - accuracy: 0.7386
# 268/268 - 0s - loss: 0.5700 - accuracy: 0.7282 - 354ms/epoch - 1ms/step
# Loss: 0.5699892640113831, Accuracy: 0.7281632423400879

# %%
# Train the model
nn.compile(optimizer='Adadelta', loss='binary_crossentropy', metrics=['accuracy'])

# Define the checkpoint path and filename
checkpoint_path = "model_weights/checkpoint_weights.{epoch:02d}.h5"

# Create a callback that saves the model's weights every five epochs
checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_path,
    save_weights_only=True,
    save_freq=5 * len(X_train_scaled),
    verbose=1)

# Train the model with the checkpoint callback
fit_model = nn.fit(X_train_scaled, y_train, epochs=100, callbacks=[checkpoint_callback])

# Evaluate the model using the test data
evaluation = nn.evaluate(X_test_scaled, y_test, verbose=2)
print(f"Loss: {evaluation[0]}, Accuracy: {evaluation[1]}")
# Out:
# Epoch 1/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5402 - accuracy: 0.7390
# Epoch 2/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5399 - accuracy: 0.7390
# Epoch 3/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5396 - accuracy: 0.7390
# Epoch 4/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5394 - accuracy: 0.7393
# Epoch 5/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5391 - accuracy: 0.7399
# Epoch 6/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5389 - accuracy: 0.7400
# Epoch 7/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5387 - accuracy: 0.7400
# Epoch 8/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5386 - accuracy: 0.7400
# Epoch 9/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5384 - accuracy: 0.7400
# Epoch 10/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5383 - accuracy: 0.7400
# Epoch 11/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5381 - accuracy: 0.7400
# Epoch 12/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5380 - accuracy: 0.7401
# Epoch 13/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5379 - accuracy: 0.7401
# Epoch 14/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5378 - accuracy: 0.7402
# Epoch 15/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5377 - accuracy: 0.7402
# Epoch 16/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5376 - accuracy: 0.7401
# Epoch 17/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5376 - accuracy: 0.7401
# Epoch 18/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5375 - accuracy: 0.7401
# Epoch 19/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5374 - accuracy: 0.7401
# Epoch 20/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5374 - accuracy: 0.7401
# Epoch 21/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5373 - accuracy: 0.7401
# Epoch 22/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5373 - accuracy: 0.7402
# Epoch 23/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5372 - accuracy: 0.7402
# Epoch 24/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5372 - accuracy: 0.7402
# Epoch 25/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5371 - accuracy: 0.7402
# Epoch 26/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5371 - accuracy: 0.7402
# Epoch 27/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5370 - accuracy: 0.7402
# Epoch 28/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5370 - accuracy: 0.7402
# Epoch 29/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5370 - accuracy: 0.7402
# Epoch 30/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5369 - accuracy: 0.7401
# Epoch 31/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5369 - accuracy: 0.7401
# Epoch 32/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5369 - accuracy: 0.7402
# Epoch 33/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5369 - accuracy: 0.7402
# Epoch 34/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5368 - accuracy: 0.7402
# Epoch 35/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5368 - accuracy: 0.7402
# Epoch 36/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5368 - accuracy: 0.7402
# Epoch 37/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5368 - accuracy: 0.7402
# Epoch 38/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5367 - accuracy: 0.7401
# Epoch 39/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5367 - accuracy: 0.7402
# Epoch 40/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5367 - accuracy: 0.7401
# Epoch 41/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5367 - accuracy: 0.7400
# Epoch 42/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5366 - accuracy: 0.7401
# Epoch 43/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5366 - accuracy: 0.7400
# Epoch 44/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5366 - accuracy: 0.7400
# Epoch 45/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5366 - accuracy: 0.7401
# Epoch 46/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5366 - accuracy: 0.7401
# Epoch 47/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5366 - accuracy: 0.7401
# Epoch 48/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5365 - accuracy: 0.7401
# Epoch 49/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5365 - accuracy: 0.7401
# Epoch 50/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5365 - accuracy: 0.7401
# Epoch 51/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5365 - accuracy: 0.7401
# Epoch 52/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5365 - accuracy: 0.7401
# Epoch 53/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5365 - accuracy: 0.7402
# Epoch 54/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5364 - accuracy: 0.7401
# Epoch 55/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5364 - accuracy: 0.7401
# Epoch 56/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5364 - accuracy: 0.7401
# Epoch 57/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5364 - accuracy: 0.7401
# Epoch 58/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5364 - accuracy: 0.7401
# Epoch 59/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5364 - accuracy: 0.7402
# Epoch 60/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5363 - accuracy: 0.7401
# Epoch 61/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5363 - accuracy: 0.7402
# Epoch 62/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5363 - accuracy: 0.7402
# Epoch 63/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5363 - accuracy: 0.7400
# Epoch 64/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5363 - accuracy: 0.7400
# Epoch 65/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5363 - accuracy: 0.7400
# Epoch 66/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5363 - accuracy: 0.7400
# Epoch 67/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5362 - accuracy: 0.7400
# Epoch 68/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5362 - accuracy: 0.7400
# Epoch 69/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5362 - accuracy: 0.7400
# Epoch 70/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5362 - accuracy: 0.7400
# Epoch 71/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5362 - accuracy: 0.7400
# Epoch 72/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5362 - accuracy: 0.7400
# Epoch 73/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5362 - accuracy: 0.7400
# Epoch 74/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5362 - accuracy: 0.7400
# Epoch 75/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5361 - accuracy: 0.7400
# Epoch 76/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5361 - accuracy: 0.7400
# Epoch 77/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5361 - accuracy: 0.7400
# Epoch 78/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5361 - accuracy: 0.7400
# Epoch 79/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5361 - accuracy: 0.7400
# Epoch 80/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5361 - accuracy: 0.7400
# Epoch 81/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5361 - accuracy: 0.7400
# Epoch 82/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5361 - accuracy: 0.7400
# Epoch 83/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5361 - accuracy: 0.7400
# Epoch 84/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5360 - accuracy: 0.7400
# Epoch 85/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5360 - accuracy: 0.7400
# Epoch 86/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5360 - accuracy: 0.7400
# Epoch 87/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5360 - accuracy: 0.7400
# Epoch 88/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5360 - accuracy: 0.7400
# Epoch 89/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5360 - accuracy: 0.7401
# Epoch 90/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5360 - accuracy: 0.7400
# Epoch 91/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5360 - accuracy: 0.7401
# Epoch 92/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5360 - accuracy: 0.7402
# Epoch 93/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5360 - accuracy: 0.7402
# Epoch 94/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5359 - accuracy: 0.7402
# Epoch 95/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5359 - accuracy: 0.7402
# Epoch 96/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5359 - accuracy: 0.7402
# Epoch 97/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5359 - accuracy: 0.7402
# Epoch 98/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5359 - accuracy: 0.7402
# Epoch 99/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5359 - accuracy: 0.7402
# Epoch 100/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5359 - accuracy: 0.7402
# 268/268 - 0s - loss: 0.5651 - accuracy: 0.7264 - 346ms/epoch - 1ms/step
# Loss: 0.5650975704193115, Accuracy: 0.7264139652252197

# %%
# Train the model
nn.compile(optimizer='Adamax', loss='binary_crossentropy', metrics=['accuracy'])

# Define the checkpoint path and filename
checkpoint_path = "model_weights/checkpoint_weights.{epoch:02d}.h5"

# Create a callback that saves the model's weights every five epochs
checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_path,
    save_weights_only=True,
    save_freq=5 * len(X_train_scaled),
    verbose=1)

# Train the model with the checkpoint callback
fit_model = nn.fit(X_train_scaled, y_train, epochs=100, callbacks=[checkpoint_callback])

# Evaluate the model using the test data
evaluation = nn.evaluate(X_test_scaled, y_test, verbose=2)
print(f"Loss: {evaluation[0]}, Accuracy: {evaluation[1]}")

# %% [markdown]
# RMSprop will be used as the optimizer for this model

# %% [markdown]
# ## Optimisation 3 - Altering the Learning Rate

# %%
# Create the RMSprop optimizer with a learning rate of 0.001
optimizer = tf.keras.optimizers.RMSprop(learning_rate=0.001)

# Compile the model with the RMSprop optimizer and binary crossentropy loss
nn.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy'])

# Train the model with the checkpoint callback
fit_model = nn.fit(X_train_scaled, y_train, epochs=100, callbacks=[checkpoint_callback])

# Evaluate the model using the test data
evaluation = nn.evaluate(X_test_scaled, y_test, verbose=2)
print(f"Loss: {evaluation[0]}, Accuracy: {evaluation[1]}")

# %%
# Create the RMSprop optimizer with a learning rate of 0.01
optimizer = tf.keras.optimizers.RMSprop(learning_rate=0.01)

# Compile the model with the RMSprop optimizer and binary crossentropy loss
nn.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy'])

# Train the model with the checkpoint callback
fit_model = nn.fit(X_train_scaled, y_train, epochs=100, callbacks=[checkpoint_callback])

# Evaluate the model using the test data
evaluation = nn.evaluate(X_test_scaled, y_test, verbose=2)
print(f"Loss: {evaluation[0]}, Accuracy: {evaluation[1]}")

# %%
# Create the RMSprop optimizer with a learning rate of 0.1
optimizer = tf.keras.optimizers.RMSprop(learning_rate=0.1)

# Compile the model with the RMSprop optimizer and binary crossentropy loss
nn.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy'])

# Train the model with the checkpoint callback
fit_model = nn.fit(X_train_scaled, y_train, epochs=100, callbacks=[checkpoint_callback])

# Evaluate the model using the test data
evaluation = nn.evaluate(X_test_scaled, y_test, verbose=2)
print(f"Loss: {evaluation[0]}, Accuracy: {evaluation[1]}")

# %% [markdown]
# The Learnign rate of 0.1 should be used as this has the higest accuracy score (70%)

# %% [markdown]
# ## Optimisation 4 - Increasing the number of Neurones

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
from tensorflow.keras.layers import Dense

nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(Dense(units=100, activation='relu', input_dim=43))

# Second hidden layer
nn.add(Dense(units=50, activation='relu'))

# Output layer
nn.add(Dense(units=1, activation='sigmoid'))

# Check the structure of the model
nn.summary()

# Create the RMSprop optimizer with a learning rate of 0.1
optimizer = tf.keras.optimizers.RMSprop(learning_rate=0.1)

# Compile the model with the RMSprop optimizer and binary crossentropy loss
nn.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy'])

# Train the model with the checkpoint callback
fit_model = nn.fit(X_train_scaled, y_train, epochs=50, callbacks=[checkpoint_callback])

# Evaluate the model using the test data
evaluation = nn.evaluate(X_test_scaled, y_test, verbose=2)
print(f"Loss: {evaluation[0]}, Accuracy: {evaluation[1]}")

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
from tensorflow.keras.layers import Dense

nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(Dense(units=40, activation='relu', input_dim=43))

# Second hidden layer
nn.add(Dense(units=15, activation='relu'))

# Output layer
nn.add(Dense(units=1, activation='sigmoid'))

# Check the structure of the model
nn.summary()

# Create the RMSprop optimizer with a learning rate of 0.1
optimizer = tf.keras.optimizers.RMSprop(learning_rate=0.1)

# Compile the model with the RMSprop optimizer and binary crossentropy loss
nn.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy'])

# Train the model with the checkpoint callback
fit_model = nn.fit(X_train_scaled, y_train, epochs=50, callbacks=[checkpoint_callback])

# Evaluate the model using the test data
evaluation = nn.evaluate(X_test_scaled, y_test, verbose=2)
print(f"Loss: {evaluation[0]}, Accuracy: {evaluation[1]}")

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
from tensorflow.keras.layers import Dense

nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(Dense(units=85, activation='relu', input_dim=43))

# Second hidden layer
nn.add(Dense(units=35, activation='relu'))

# Output layer
nn.add(Dense(units=1, activation='sigmoid'))

# Check the structure of the model
nn.summary()

# Create the RMSprop optimizer with a learning rate of 0.1
optimizer = tf.keras.optimizers.RMSprop(learning_rate=0.1)

# Compile the model with the RMSprop optimizer and binary crossentropy loss
nn.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy'])

# Train the model with the checkpoint callback
fit_model = nn.fit(X_train_scaled, y_train, epochs=50, callbacks=[checkpoint_callback])

# Evaluate the model using the test data
evaluation = nn.evaluate(X_test_scaled, y_test, verbose=2)
print(f"Loss: {evaluation[0]}, Accuracy: {evaluation[1]}")

# %% [markdown]
# 80 for the first layer and 30 for the second layer povided the highest accuracy so I will not change these parameters.

# %% [markdown]
# ## Optimisation 5 - Adding More Layers

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
from tensorflow.keras.layers import Dense

nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(Dense(units=80, activation='relu', input_dim=43))

# Second hidden layer
nn.add(Dense(units=30, activation='relu'))

# Third hidden layer
nn.add(Dense(units=30, activation='tanh'))

# Output layer
nn.add(Dense(units=1, activation='sigmoid'))

# Check the structure of the model
nn.summary()

# Create the RMSprop optimizer with a learning rate of 0.1
optimizer = tf.keras.optimizers.RMSprop(learning_rate=0.1)

# Compile the model with the RMSprop optimizer and binary crossentropy loss
nn.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy'])

# Train the model with the checkpoint callback
fit_model = nn.fit(X_train_scaled, y_train, epochs=50, callbacks=[checkpoint_callback])

# Evaluate the model using the test data
evaluation = nn.evaluate(X_test_scaled, y_test, verbose=2)
print(f"Loss: {evaluation[0]}, Accuracy: {evaluation[1]}")
